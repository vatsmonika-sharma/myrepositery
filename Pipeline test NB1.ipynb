# %%
# %sql
CREATE CATALOG if not EXISTS my_catalog
--MANAGED LOCATION 'abfss://metastoreroot@mksstorageaccount001.dfs.core.windows.net/'

# %%
# %sql
    
Create schema IF NOT EXISTS my_catalog.my_schema

# %%
# %sql
CREATE TABLE IF NOT EXISTS my_catalog.my_schema.bronze_sales (
    order_id STRING,
    customer_id STRING,
    product_id STRING,
    amount DOUBLE,
    order_date STRING
)
USING DELTA;

# %%
# %sql
-- Load sample data (simulate ingestion)
INSERT INTO my_catalog.my_schema.bronze_sales VALUES
('1','C1','P1',100,'2024-01-01'),
('2','C2','P2',200,'2024-01-02'),
('3','C1','P3',150,'2024-01-02'),
('3','C1','P3',150,'2024-01-02'); -- duplicate
